# %% [markdown]
# # DBMS PROJECT - PREPROCESSING

# %% [markdown]
# ---

# %% [markdown]
# ## Import Libraries

# %%
import json
import pandas as pd
import numpy as np

# %% [markdown]
# ## Columns Description

# %% [markdown]
# - "created_at": The timestamp for when the tweet was created (in UTC time).
# - "id": The unique ID of the tweet.
# - "id_str": The string representation of the unique tweet ID.
# - "text": The content of the tweet.
# - "source": The application or device used to post the tweet.
# - "truncated": Indicates whether the tweet has been truncated.
# - "in_reply_to_status_id": The unique ID of the status being replied to, if the tweet is a reply.
# - "in_reply_to_status_id_str": The string representation of the ID of the status being replied to, if the tweet is a reply.
# - "in_reply_to_user_id": The unique ID of the user being replied to, if the tweet is a reply.
# - "in_reply_to_user_id_str": The string representation of the unique user ID of the user being replied to, if the tweet is a reply.
# - "in_reply_to_screen_name": The screen name of the user being replied to, if the tweet is a reply.
# - "user": An object containing information about the user who posted the tweet.
# - "geo": The geographic location of the tweet, if available.
# - "coordinates": The coordinates of the tweet, if available.
# - "place": The place associated with the tweet, if available.
# - "contributors": An array of contributors to the tweet.
# - "retweeted_status": If the tweet is a retweet, this object contains information about the original tweet that was retweeted.

# %% [markdown]
# ## Data Load using New Line Split

# %%
data_path = 'Eurovision8.json'

# %%
with open(data_path) as f:
    print(type(f.read().split('\n')))
# Out:
# <class 'list'>

# %%
contents = []
with open(data_path) as f:
    for data_str in f.read().split('\n'):
        if data_str:
            data = json.loads(data_str)
            contents.append(data)

# %% [markdown]
# ## Data Sample for Testing and understanding Schema

# %% [markdown]
# ---

# %%
# Load the JSON data from a file
with open(data_path) as f:
    data_str = f.read().split('\n')[0]  # Read only the first line of the file
    data_sample = json.loads(data_str)

# %%
data_sample
# Out:
# {'created_at': 'Sat May 12 22:22:28 +0000 2018',
#  'id': 995429025676972032,
#  'id_str': '995429025676972032',
#  'text': 'RT @BuzzFeedFrance: En réel, on adore Elodie Gossuin, elle fait toujours un effort pour être originale ! #Eurovision https://t.co/L0aw2frKRM',
#  'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#  'truncated': False,
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'in_reply_to_screen_name': None,
#  'user': {'id': 309561448,
#   'id_str': '309561448',
#   'name': 'Marjorie 🌸',
#   'screen_name': 'london_mb',
#   'location': 'Mustard city',
#   'url': 'https://www.instagram.com/mipequenocorazoncito/',
#   'description': 'Ex-Expat 🇬🇧 🇨🇴  \nCat, Music & Cinema lover.\n\n\n\n\n\nMum of a babygirl ❤',
#   'translator_type': 'none',
#   'protected': False,
#   'verified': False,
#   'followers_count': 368,
#   'friends_count': 818,
#   'listed_count': 31,
#   'favourites_count': 53,
#   'statuses_count': 6519,
#   'created_at': 'Thu Jun 02 09:03:37 +0000 2011',
#   'utc_offset': 3600,
#   'time_zone': 'London',
#   'geo_enabled': True,
#   'lang': 'en',
#   'contributors_enabled': False,
#   'is_translator': False,
#   'profile_background_color': '000000',
#   'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme15/bg.png',
#   'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme15/bg.png',
#   'profile_background_tile': False,
#   'profile_link_color': 'E81C4F',
#   'profile_sidebar_border_color': '000000',
#   'profile_sidebar_fill_color': '000000',
#   'profile_text_color': '000000',
#   'profile_use_background_image': False,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/909823370912550912/jaP9FqXc_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/909823370912550912/jaP9FqXc_normal.jpg',
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/309561448/1496995707',
#   'default_profile': False,
#   'default_profile_image': False,
#   'following': None,
#   'follow_request_sent': None,
#   'notifications': None},
#  'geo': None,
#  'coordinates': None,
#  'place': None,
#  'contributors': None,
#  'retweeted_status': {'created_at': 'Sat May 12 22:16:18 +0000 2018',
#   'id': 995427474262675456,
#   'id_str': '995427474262675456',
#   'text': 'En réel, on adore Elodie Gossuin, elle fait toujours un effort pour être originale ! #Eurovision https://t.co/L0aw2frKRM',
#   'display_text_range': [0, 96],
#   'source': '<a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>',
#   'truncated': False,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 1798205671,
#    'id_str': '1798205671',
#    'name': 'BuzzFeed France',
#    'screen_name': 'BuzzFeedFrance',
#    'location': 'Paris, France',
#    'url': 'http://buzzfeed.com',
#    'description': "Ça mérite d'être partagé",
#    'translator_type': 'none',
#    'protected': False,
#    'verified': True,
#    'followers_count': 30614,
#    'friends_count': 315,
#    'listed_count': 535,
#    'favourites_count': 1513,
#    'statuses_count': 42258,
#    'created_at': 'Sun Sep 08 02:46:06 +0000 2013',
#    'utc_offset': -14400,
#    'time_zone': 'Eastern Time (US & Canada)',
#    'geo_enabled': False,
#    'lang': 'fr',
#    'contributors_enabled': False,
#    'is_translator': False,
#    'profile_background_color': '9AE4E8',
#    'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/501742057002520576/Ln3ibc9F.jpeg',
#    'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/501742057002520576/Ln3ibc9F.jpeg',
#    'profile_background_tile': True,
#    'profile_link_color': '0084B4',
#    'profile_sidebar_border_color': 'FFFFFF',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/720581471300243456/gj2pjSF-_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/720581471300243456/gj2pjSF-_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1798205671/1460635048',
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': None,
#    'follow_request_sent': None,
#    'notifications': None},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'quote_count': 3,
#   'reply_count': 7,
#   'retweet_count': 50,
#   'favorite_count': 142,
#   'entities': {'hashtags': [{'text': 'Eurovision', 'indices': [85, 96]}],
#    'urls': [],
#    'user_mentions': [],
#    'symbols': [],
#    'media': [{'id': 995427375004471296,
#      'id_str': '995427375004471296',
#      'indices': [97, 120],
#      'media_url': 'http://pbs.twimg.com/tweet_video_thumb/DdB37G7XUAA56ku.jpg',
#      'media_url_https': 'https://pbs.twimg.com/tweet_video_thumb/DdB37G7XUAA56ku.jpg',
#      'url': 'https://t.co/L0aw2frKRM',
#      'display_url': 'pic.twitter.com/L0aw2frKRM',
#      'expanded_url': 'https://twitter.com/BuzzFeedFrance/status/995427474262675456/photo/1',
#      'type': 'photo',
#      'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#       'large': {'w': 500, 'h': 280, 'resize': 'fit'},
#       'small': {'w': 500, 'h': 280, 'resize': 'fit'},
#       'medium': {'w': 500, 'h': 280, 'resize': 'fit'}}}]},
#   'extended_entities': {'media': [{'id': 995427375004471296,
#      'id_str': '995427375004471296',
#      'indices': [97, 120],
#      'media_url': 'http://pbs.twimg.com/tweet_video_thumb/DdB37G7XUAA56ku.jpg',
#      'media_url_https': 'https://pbs.twimg.com/tweet_video_thumb/DdB37G7XUAA56ku.jpg',
#      'url': 'https://t.co/L0aw2frKRM',
#      'display_url': 'pic.twitter.com/L0aw2frKRM',
#      'expanded_url': 'https://twitter.com/BuzzFeedFrance/status/995427474262675456/photo/1',
#      'type': 'animated_gif',
#      'video_info': {'aspect_ratio': [25, 14],
#       'variants': [{'bitrate': 0,
#         'content_type': 'video/mp4',
#         'url': 'https://video.twimg.com/tweet_video/DdB37G7XUAA56ku.mp4'}]},
#      'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#       'large': {'w': 500, 'h': 280, 'resize': 'fit'},
#       'small': {'w': 500, 'h': 280, 'resize': 'fit'},
#       'medium': {'w': 500, 'h': 280, 'resize': 'fit'}}}]},
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'filter_level': 'low',
#   'lang': 'fr'},
#  'is_quote_status': False,
#  'quote_count': 0,
#  'reply_count': 0,
#  'retweet_count': 0,
#  'favorite_count': 0,
#  'entities': {'hashtags': [{'text': 'Eurovision', 'indices': [105, 116]}],
#   'urls': [],
#   'user_mentions': [{'screen_name': 'BuzzFeedFrance',
#     'name': 'BuzzFeed France',
#     'id': 1798205671,
#     'id_str': '1798205671',
#     'indices': [3, 18]}],
#   'symbols': [],
#   'media': [{'id': 995427375004471296,
#     'id_str': '995427375004471296',
#     'indices': [117, 140],
#     'media_url': 'http://pbs.twimg.com/tweet_video_thumb/DdB37G7XUAA56ku.jpg',
#     'media_url_https': 'https://pbs.twimg.com/tweet_video_thumb/DdB37G7XUAA56ku.jpg',
#     'url': 'https://t.co/L0aw2frKRM',
#     'display_url': 'pic.twitter.com/L0aw2frKRM',
#     'expanded_url': 'https://twitter.com/BuzzFeedFrance/status/995427474262675456/photo/1',
#     'type': 'photo',
#     'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#      'large': {'w': 500, 'h': 280, 'resize': 'fit'},
#      'small': {'w': 500, 'h': 280, 'resize': 'fit'},
#      'medium': {'w': 500, 'h': 280, 'resize': 'fit'}},
#     'source_status_id': 995427474262675456,
#     'source_status_id_str': '995427474262675456',
#     'source_user_id': 1798205671,
#     'source_user_id_str': '1798205671'}]},
#  'extended_entities': {'media': [{'id': 995427375004471296,
#     'id_str': '995427375004471296',
#     'indices': [117, 140],
#     'media_url': 'http://pbs.twimg.com/tweet_video_thumb/DdB37G7XUAA56ku.jpg',
#     'media_url_https': 'https://pbs.twimg.com/tweet_video_thumb/DdB37G7XUAA56ku.jpg',
#     'url': 'https://t.co/L0aw2frKRM',
#     'display_url': 'pic.twitter.com/L0aw2frKRM',
#     'expanded_url': 'https://twitter.com/BuzzFeedFrance/status/995427474262675456/photo/1',
#     'type': 'animated_gif',
#     'video_info': {'aspect_ratio': [25, 14],
#      'variants': [{'bitrate': 0,
#        'content_type': 'video/mp4',
#        'url': 'https://video.twimg.com/tweet_video/DdB37G7XUAA56ku.mp4'}]},
#     'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#      'large': {'w': 500, 'h': 280, 'resize': 'fit'},
#      'small': {'w': 500, 'h': 280, 'resize': 'fit'},
#      'medium': {'w': 500, 'h': 280, 'resize': 'fit'}},
#     'source_status_id': 995427474262675456,
#     'source_status_id_str': '995427474262675456',
#     'source_user_id': 1798205671,
#     'source_user_id_str': '1798205671'}]},
#  'favorited': False,
#  'retweeted': False,
#  'possibly_sensitive': False,
#  'filter_level': 'low',
#  'lang': 'fr',
#  'timestamp_ms': '1526163748555'}

# %% [markdown]
# ---

# %%
df = pd.DataFrame(contents)

# %% [markdown]
# ## Null ID Treatment: Removing Null IDs

# %%
df_notnull = df.loc[df['id'].notna(), :]

# %%
df_notnull.head()
# Out:
#                        created_at            id              id_str  \
# 0  Sat May 12 22:22:28 +0000 2018  9.954290e+17  995429025676972032
# 1  Sat May 12 22:22:28 +0000 2018  9.954290e+17  995429025924419584
# 2  Sat May 12 22:22:28 +0000 2018  9.954290e+17  995429025614090240
# 3  Sat May 12 22:22:28 +0000 2018  9.954290e+17  995429025995788294
# 4  Sat May 12 22:22:28 +0000 2018  9.954290e+17  995429026180358144
#
#                                                 text  \
# 0  RT @BuzzFeedFrance: En réel, on adore Elodie G...
# 1  @GuyOverboard @matteowolk @NaliOfficial No io ...
# 2  RT @jk_rowling: Apparently the Australian comm...
# 3  RT @ElAbu__: Turismo de borrachera ! que sepái...
# 4  RT @RitaListing: Sempre que alguém dá 12 ponto...
#
#                                               source truncated  \
# 0  <a href="http://twitter.com/download/android" ...     False
# 1  <a href="http://twitter.com/download/android" ...     False
# 2  <a href="http://twitter.com/download/android" ...     False
# 3  <a href="http://twitter.com/download/iphone" r...     False
# 4  <a href="http://twitter.com/download/iphone" r...     False
#
#    in_reply_to_status_id in_reply_to_status_id_str  in_reply_to_user_id  \
# 0                    NaN                      None                  NaN
# 1           9.954286e+17        995428578153189377          585866849.0
# 2                    NaN                      None                  NaN
# 3                    NaN                      None                  NaN
# 4                    NaN                      None                  NaN
#
#   in_reply_to_user_id_str  ... filter_level lang   timestamp_ms  \
# 0                    None  ...          low   fr  1526163748555
# 1               585866849  ...          low   it  1526163748614
# 2                    None  ...          low   en  1526163748540
# 3                    None  ...          low   es  1526163748631
# 4                    None  ...          low   pt  1526163748675
#
#   display_text_range quoted_status_id  quoted_status_id_str quoted_status  \
# 0                NaN              NaN                   NaN           NaN
# 1          [40, 135]              NaN                   NaN           NaN
# 2                NaN              NaN                   NaN           NaN
# 3                NaN              NaN                   NaN           NaN
# 4                NaN              NaN                   NaN           NaN
#
#   limit  extended_tweet  withheld_in_countries
# 0   NaN             NaN                    NaN
# 1   NaN             NaN                    NaN
# 2   NaN             NaN                    NaN
# 3   NaN             NaN                    NaN
# 4   NaN             NaN                    NaN
#
# [5 rows x 37 columns]

# %%
df_notnull.columns
# Out:
# Index(['created_at', 'id', 'id_str', 'text', 'source', 'truncated',
#        'in_reply_to_status_id', 'in_reply_to_status_id_str',
#        'in_reply_to_user_id', 'in_reply_to_user_id_str',
#        'in_reply_to_screen_name', 'user', 'geo', 'coordinates', 'place',
#        'contributors', 'retweeted_status', 'is_quote_status', 'quote_count',
#        'reply_count', 'retweet_count', 'favorite_count', 'entities',
#        'extended_entities', 'favorited', 'retweeted', 'possibly_sensitive',
#        'filter_level', 'lang', 'timestamp_ms', 'display_text_range',
#        'quoted_status_id', 'quoted_status_id_str', 'quoted_status', 'limit',
#        'extended_tweet', 'withheld_in_countries'],
#       dtype='object')

# %% [markdown]
# ## Flatten Nested JSON and Join it back with the data based on Indexing

# %%
# define a function to split the dictionary columns into separate columns
def split_dict_columns(df, columns):
    for column in columns:
        # use pd.Series constructor to split the dictionary column into separate columns
        split_df = pd.DataFrame(df[column].tolist())
        # add the new columns to the original dataframe
        for col in split_df.columns:
            df[f"{column}_{col}"] = split_df[col]

        # remove the original column
        df.drop(column, axis=1, inplace=True)
    return df

# call the function with the dataframe and the columns to split
df_norm = split_dict_columns(df_notnull, ['user', 'entities'])
# Out:
# <ipython-input-10-80b886ba0ff3>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f"{column}_{col}"] = split_df[col]
# C:\Users\akshit73\anaconda3\lib\site-packages\pandas\core\frame.py:4163: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
df_norm.head()
# Out:
#                        created_at            id              id_str  \
# 0  Sat May 12 22:22:28 +0000 2018  9.954290e+17  995429025676972032
# 1  Sat May 12 22:22:28 +0000 2018  9.954290e+17  995429025924419584
# 2  Sat May 12 22:22:28 +0000 2018  9.954290e+17  995429025614090240
# 3  Sat May 12 22:22:28 +0000 2018  9.954290e+17  995429025995788294
# 4  Sat May 12 22:22:28 +0000 2018  9.954290e+17  995429026180358144
#
#                                                 text  \
# 0  RT @BuzzFeedFrance: En réel, on adore Elodie G...
# 1  @GuyOverboard @matteowolk @NaliOfficial No io ...
# 2  RT @jk_rowling: Apparently the Australian comm...
# 3  RT @ElAbu__: Turismo de borrachera ! que sepái...
# 4  RT @RitaListing: Sempre que alguém dá 12 ponto...
#
#                                               source truncated  \
# 0  <a href="http://twitter.com/download/android" ...     False
# 1  <a href="http://twitter.com/download/android" ...     False
# 2  <a href="http://twitter.com/download/android" ...     False
# 3  <a href="http://twitter.com/download/iphone" r...     False
# 4  <a href="http://twitter.com/download/iphone" r...     False
#
#    in_reply_to_status_id in_reply_to_status_id_str  in_reply_to_user_id  \
# 0                    NaN                      None                  NaN
# 1           9.954286e+17        995428578153189377          585866849.0
# 2                    NaN                      None                  NaN
# 3                    NaN                      None                  NaN
# 4                    NaN                      None                  NaN
#
#   in_reply_to_user_id_str  ... user_default_profile  \
# 0                    None  ...                False
# 1               585866849  ...                False
# 2                    None  ...                False
# 3                    None  ...                False
# 4                    None  ...                False
#
#   user_default_profile_image user_following user_follow_request_sent  \
# 0                      False           None                     None
# 1                      False           None                     None
# 2                      False           None                     None
# 3                      False           None                     None
# 4                      False           None                     None
#
#    user_notifications                                entities_hashtags  \
# 0                None  [{'text': 'Eurovision', 'indices': [105, 116]}]
# 1                None                                               []
# 2                None                                               []
# 3                None  [{'text': 'eurovision', 'indices': [103, 114]}]
# 4                None    [{'text': 'Eurovision', 'indices': [58, 69]}]
#
#   entities_urls                             entities_user_mentions  \
# 0            []  [{'screen_name': 'BuzzFeedFrance', 'name': 'Bu...
# 1            []  [{'screen_name': 'GuyOverboard', 'name': 'Ricc...
# 2            []  [{'screen_name': 'jk_rowling', 'name': 'J.K. R...
# 3            []  [{'screen_name': 'ElAbu__', 'name': 'El Abu', ...
# 4            []  [{'screen_name': 'RitaListing', 'name': 'Rita ...
#
#    entities_symbols                                     entities_media
# 0                []  [{'id': 995427375004471296, 'id_str': '9954273...
# 1                []                                                NaN
# 2                []                                                NaN
# 3                []  [{'id': 995427620807499777, 'id_str': '9954276...
# 4                []  [{'id': 995427614503383041, 'id_str': '9954276...
#
# [5 rows x 79 columns]

# %% [markdown]
# ## Create Deep Copy of DataFrame

# %%
df_norm_2 = df_norm.copy(deep = True)

# %%
df_norm_2.head()
# Out:
#                             created_at            id              id_str  \
# 0       Sat May 12 22:22:28 +0000 2018  9.954290e+17  995429025676972032
# 1       Sat May 12 22:22:28 +0000 2018  9.954290e+17  995429025924419584
# 2       Sat May 12 22:22:28 +0000 2018  9.954290e+17  995429025614090240
# 3       Sat May 12 22:22:28 +0000 2018  9.954290e+17  995429025995788294
# 4       Sat May 12 22:22:28 +0000 2018  9.954290e+17  995429026180358144
# ...                                ...           ...                 ...
# 113875  Sat May 12 22:58:57 +0000 2018  9.954382e+17  995438207926812672
# 113876  Sat May 12 22:58:57 +0000 2018  9.954382e+17  995438208082153472
# 113877  Sat May 12 22:58:57 +0000 2018  9.954382e+17  995438208208031744
# 113878  Sat May 12 22:58:57 +0000 2018  9.954382e+17  995438208002424832
# 113879  Sat May 12 22:58:57 +0000 2018  9.954382e+17  995438208342257664
#
#                                                      text  \
# 0       RT @BuzzFeedFrance: En réel, on adore Elodie G...
# 1       @GuyOverboard @matteowolk @NaliOfficial No io ...
# 2       RT @jk_rowling: Apparently the Australian comm...
# 3       RT @ElAbu__: Turismo de borrachera ! que sepái...
# 4       RT @RitaListing: Sempre que alguém dá 12 ponto...
# ...                                                   ...
# 113875  #dieudonné #soral  #Israel a gagné l'Eurovisio...
# 113876  RT @AnthonyJzql: Dans un moment d'égarement j'...
# 113877  RT @insoniascarvao: 😱 #Eurovision https://t.co...
# 113878  RT @PerfWolf: #Eurovision 2017: La victoria de...
# 113879     RT @glowyhyuck: eurovision 2018 never happened
#
#                                                    source truncated  \
# 0       <a href="http://twitter.com/download/android" ...     False
# 1       <a href="http://twitter.com/download/android" ...     False
# 2       <a href="http://twitter.com/download/android" ...     False
# 3       <a href="http://twitter.com/download/iphone" r...     False
# 4       <a href="http://twitter.com/download/iphone" r...     False
# ...                                                   ...       ...
# 113875  <a href="http://twitter.com/download/android" ...     False
# 113876  <a href="http://twitter.com/download/iphone" r...     False
# 113877  <a href="http://twitter.com/download/iphone" r...     False
# 113878  <a href="http://twitter.com/download/android" ...     False
# 113879  <a href="http://twitter.com/download/android" ...     False
#
#         in_reply_to_status_id in_reply_to_status_id_str  in_reply_to_user_id  \
# 0                         NaN                      None                  NaN
# 1                9.954286e+17        995428578153189377          585866849.0
# 2                         NaN                      None                  NaN
# 3                         NaN                      None                  NaN
# 4                         NaN                      None                  NaN
# ...                       ...                       ...                  ...
# 113875                    NaN                      None                  NaN
# 113876                    NaN                      None                  NaN
# 113877                    NaN                      None                  NaN
# 113878                    NaN                      None                  NaN
# 113879                    NaN                      None                  NaN
#
#        in_reply_to_user_id_str  ... user_default_profile  \
# 0                         None  ...                False
# 1                    585866849  ...                False
# 2                         None  ...                False
# 3                         None  ...                False
# 4                         None  ...                False
# ...                        ...  ...                  ...
# 113875                    None  ...                  NaN
# 113876                    None  ...                  NaN
# 113877                    None  ...                  NaN
# 113878                    None  ...                  NaN
# 113879                    None  ...                  NaN
#
#        user_default_profile_image user_following user_follow_request_sent  \
# 0                           False           None                     None
# 1                           False           None                     None
# 2                           False           None                     None
# 3                           False           None                     None
# 4                           False           None                     None
# ...                           ...            ...                      ...
# 113875                        NaN            NaN                      NaN
# 113876                        NaN            NaN                      NaN
# 113877                        NaN            NaN                      NaN
# 113878                        NaN            NaN                      NaN
# 113879                        NaN            NaN                      NaN
#
#         user_notifications                                entities_hashtags  \
# 0                     None  [{'text': 'Eurovision', 'indices': [105, 116]}]
# 1                     None                                               []
# 2                     None                                               []
# 3                     None  [{'text': 'eurovision', 'indices': [103, 114]}]
# 4                     None    [{'text': 'Eurovision', 'indices': [58, 69]}]
# ...                    ...                                              ...
# 113875                 NaN                                              NaN
# 113876                 NaN                                              NaN
# 113877                 NaN                                              NaN
# 113878                 NaN                                              NaN
# 113879                 NaN                                              NaN
#
#        entities_urls                             entities_user_mentions  \
# 0                 []  [{'screen_name': 'BuzzFeedFrance', 'name': 'Bu...
# 1                 []  [{'screen_name': 'GuyOverboard', 'name': 'Ricc...
# 2                 []  [{'screen_name': 'jk_rowling', 'name': 'J.K. R...
# 3                 []  [{'screen_name': 'ElAbu__', 'name': 'El Abu', ...
# 4                 []  [{'screen_name': 'RitaListing', 'name': 'Rita ...
# ...              ...                                                ...
# 113875           NaN                                                NaN
# 113876           NaN                                                NaN
# 113877           NaN                                                NaN
# 113878           NaN                                                NaN
# 113879           NaN                                                NaN
#
#         entities_symbols                                     entities_media
# 0                     []  [{'id': 995427375004471296, 'id_str': '9954273...
# 1                     []                                                NaN
# 2                     []                                                NaN
# 3                     []  [{'id': 995427620807499777, 'id_str': '9954276...
# 4                     []  [{'id': 995427614503383041, 'id_str': '9954276...
# ...                  ...                                                ...
# 113875               NaN                                                NaN
# 113876               NaN                                                NaN
# 113877               NaN                                                NaN
# 113878               NaN                                                NaN
# 113879               NaN                                                NaN
#
# [105124 rows x 79 columns]

# %% [markdown]
# ## Entities Hashtags: Dealing with multi-nested JSON within rows
#
# Entities Hashtags have a different structure:
#
# - Nested JSON within each row
# - Null Values that won't flatten out(gives len(float) error)

# %%
data = [i for i in df_norm_2['entities_hashtags'].fillna({i: [{}] for i in df_norm_2.index}).tolist() if i]
df_temp = pd.DataFrame([item for sublist in data for item in sublist])
df_temp = df_temp.loc[df_temp['text'].notnull(), :]
for col in df_temp.columns:
    df_norm_2[f'entities_hashtags_{col}'] = df_temp[col]
# remove the original column
df_norm_2.drop('entities_hashtags', axis=1, inplace=True)

# %% [markdown]
# **Data -> Entities -> Entities_Hashtags**

# %%
df_norm_2.head()
# Out:
#                        created_at            id              id_str  \
# 0  Sat May 12 22:22:28 +0000 2018  9.954290e+17  995429025676972032
# 1  Sat May 12 22:22:28 +0000 2018  9.954290e+17  995429025924419584
# 2  Sat May 12 22:22:28 +0000 2018  9.954290e+17  995429025614090240
# 3  Sat May 12 22:22:28 +0000 2018  9.954290e+17  995429025995788294
# 4  Sat May 12 22:22:28 +0000 2018  9.954290e+17  995429026180358144
#
#                                                 text  \
# 0  RT @BuzzFeedFrance: En réel, on adore Elodie G...
# 1  @GuyOverboard @matteowolk @NaliOfficial No io ...
# 2  RT @jk_rowling: Apparently the Australian comm...
# 3  RT @ElAbu__: Turismo de borrachera ! que sepái...
# 4  RT @RitaListing: Sempre que alguém dá 12 ponto...
#
#                                               source truncated  \
# 0  <a href="http://twitter.com/download/android" ...     False
# 1  <a href="http://twitter.com/download/android" ...     False
# 2  <a href="http://twitter.com/download/android" ...     False
# 3  <a href="http://twitter.com/download/iphone" r...     False
# 4  <a href="http://twitter.com/download/iphone" r...     False
#
#    in_reply_to_status_id in_reply_to_status_id_str  in_reply_to_user_id  \
# 0                    NaN                      None                  NaN
# 1           9.954286e+17        995428578153189377          585866849.0
# 2                    NaN                      None                  NaN
# 3                    NaN                      None                  NaN
# 4                    NaN                      None                  NaN
#
#   in_reply_to_user_id_str  ... user_default_profile_image user_following  \
# 0                    None  ...                      False           None
# 1               585866849  ...                      False           None
# 2                    None  ...                      False           None
# 3                    None  ...                      False           None
# 4                    None  ...                      False           None
#
#   user_follow_request_sent user_notifications  entities_urls  \
# 0                     None               None             []
# 1                     None               None             []
# 2                     None               None             []
# 3                     None               None             []
# 4                     None               None             []
#
#                               entities_user_mentions entities_symbols  \
# 0  [{'screen_name': 'BuzzFeedFrance', 'name': 'Bu...               []
# 1  [{'screen_name': 'GuyOverboard', 'name': 'Ricc...               []
# 2  [{'screen_name': 'jk_rowling', 'name': 'J.K. R...               []
# 3  [{'screen_name': 'ElAbu__', 'name': 'El Abu', ...               []
# 4  [{'screen_name': 'RitaListing', 'name': 'Rita ...               []
#
#                                       entities_media  entities_hashtags_text  \
# 0  [{'id': 995427375004471296, 'id_str': '9954273...              Eurovision
# 1                                                NaN              eurovision
# 2                                                NaN              Eurovision
# 3  [{'id': 995427620807499777, 'id_str': '9954276...                 Austria
# 4  [{'id': 995427614503383041, 'id_str': '9954276...              Eurovision
#
#    entities_hashtags_indices
# 0                 [105, 116]
# 1                 [103, 114]
# 2                   [58, 69]
# 3                   [39, 47]
# 4                   [49, 60]
#
# [5 rows x 80 columns]

# %% [markdown]
# ## Export to CSV
#
# This gives problems in Spark as there are comma separated values within tweet texts and other columns and that messes up the schema loading structure when converting CSV to Spark Dataframe

# %%
df_norm_2.to_csv('DBMS_EUROVISION_TWITTER.csv', index = False)

# %% [markdown]
# ## Export to JSON
#
# Solution to previous problem: Upload JSON data to Spark(Azure)
#
# Before exporting: Clear out the rows with null user_ids: we don't need this

# %%
df_norm_2_notnull = df_norm_2.loc[df_norm_2['user_id'].notnull(), :]
df_norm_2_notnull.to_json('DBMS_EUROVISION_TWITTER.json')

# %% [markdown]
# ## EDA to check whether data conversion(nesting and flattening was successful) and query result comparison to Spark SQL

# %%
df_norm_2['user_id_str'].value_counts()
# Out:
# 2582441749            31
# 1367380723            30
# 718489648033579008    29
# 912345998             24
# 1015176752            23
#                       ..
# 140127062              1
# 740032149403750400     1
# 476101959              1
# 595833899              1
# 916593465911324672     1
# Name: user_id_str, Length: 68147, dtype: int64

# %%
df_norm_2['is_quote_status'].value_counts()
# Out:
# False    99841
# True      5283
# Name: is_quote_status, dtype: int64

# %%
df_norm.loc[df_norm_2['user_screen_name'] == 'blcklcfr', 'user_id_str']
# Out:
# 33971    945629878153510912
# 40582    945629878153510912
# Name: user_id_str, dtype: object

# %%
df_norm.loc[df_norm['id_str'] == '945629878153510912', 'in_reply_to_user_id']
# Out:
# Series([], Name: in_reply_to_user_id, dtype: float64)

# %%
df_norm.loc[df_norm['user_id_str'] == '309561448', :]
# Out:
#                            created_at            id              id_str  \
# 0      Sat May 12 22:22:28 +0000 2018  9.954290e+17  995429025676972032
# 22532  Sat May 12 22:29:41 +0000 2018  9.954308e+17  995430842376835072
# 35626  Sat May 12 22:33:53 +0000 2018  9.954319e+17  995431899274403852
#
#                                                     text  \
# 0      RT @BuzzFeedFrance: En réel, on adore Elodie G...
# 22532  RT @Hunter_GS: "i dont even know what the fuck...
# 35626     OOOH PEUT ETRE L'ALLEMAGNE ALORS ? #Eurovision
#
#                                                   source truncated  \
# 0      <a href="http://twitter.com/download/android" ...     False
# 22532  <a href="http://twitter.com" rel="nofollow">Tw...     False
# 35626  <a href="http://twitter.com" rel="nofollow">Tw...     False
#
#        in_reply_to_status_id in_reply_to_status_id_str  in_reply_to_user_id  \
# 0                        NaN                      None                  NaN
# 22532                    NaN                      None                  NaN
# 35626                    NaN                      None                  NaN
#
#       in_reply_to_user_id_str  ... user_default_profile  \
# 0                        None  ...                False
# 22532                    None  ...                False
# 35626                    None  ...                False
#
#       user_default_profile_image user_following user_follow_request_sent  \
# 0                          False           None                     None
# 22532                      False           None                     None
# 35626                      False           None                     None
#
#        user_notifications                                entities_hashtags  \
# 0                    None  [{'text': 'Eurovision', 'indices': [105, 116]}]
# 22532                None    [{'text': 'Eurovision', 'indices': [14, 25]}]
# 35626                None    [{'text': 'Eurovision', 'indices': [40, 51]}]
#
#       entities_urls                             entities_user_mentions  \
# 0                []  [{'screen_name': 'BuzzFeedFrance', 'name': 'Bu...
# 22532            []  [{'screen_name': 'EdChirac', 'name': 'Ed Chira...
# 35626            []  [{'screen_name': 'Queen_UK', 'name': 'Elizabet...
#
#        entities_symbols                                     entities_media
# 0                    []  [{'id': 995427375004471296, 'id_str': '9954273...
# 22532                []                                                NaN
# 35626                []                                                NaN
#
# [3 rows x 79 columns]
